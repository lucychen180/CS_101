# %% [markdown]
# Inspired by an image deblurring paper: https://ieeexplore.ieee.org/document/6420015

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, Conv2D, Flatten, core, BatchNormalization, Conv2DTranspose
import ehtim as eh
import numpy as np
import matplotlib.pyplot as plt
# visibilities
INPUT_SIZE = 1030
# pixels in image
OUTPUT_SIZE = 784

# %%
IM = eh.image.load_txt('../models/avery_sgra_eofn.txt');
IM = IM.resample_square(28)

def displayImage(arr):
    """Displays image given a flattened array of pixels."""
    IM.imvec = arr
    IM.display()
# Out:
# Loading text image:  ../models/avery_sgra_eofn.txt

# %%
def getData(start, end):
    """Reads in visibilities and image from [start, end)."""
    n = end - start
    x, y = np.empty([n, INPUT_SIZE]), np.empty([n, OUTPUT_SIZE])
    for i in range(n):
        obs = eh.obsdata.load_uvfits('../data/trainA/obs{0}.fits'.format(start + i))
        im = eh.image.load_fits('../data/trainB/img{0}.fits'.format(start + i))
        x[i] = obs.data['vis']
        y[i] = im.imvec
    return x, y

# %%
#x_train, y_train = getData(10000, 18000)

# %%
np.save('x_10000-18000.npy', x_train)
np.save('y_10000-18000.npy', y_train)

# %%
x_1 = np.load('x_10000-18000.npy')
y_1 = np.load('y_10000-18000.npy')

# %%
for i in range(0,len(y_1)):
    y_1[i] = y_1[i] * 784

# %%
# Out:
# 1.0

# %%
# Neural Net
model = Sequential()
model.add(Dense(900, input_dim=INPUT_SIZE, activation='sigmoid', name='l1'))
model.add(core.Reshape((30, 10, 3)))
model.add(Conv2DTranspose(18, 9, activation='sigmoid', input_shape=(30, 10, 3)))
model.add(BatchNormalization(axis=-1))
model.add(Flatten())
model.add(Dense(OUTPUT_SIZE, activation='relu'))
model.compile(loss='mse', optimizer='adam')
info = model.fit(x_1, y_1, epochs=50, batch_size=64, validation_split=0.3)
# Out:
# Train on 5600 samples, validate on 2400 samples
# Epoch 1/50
# 5600/5600 [==============================] - 54s 10ms/step - loss: 2.6220 - val_loss: 2.4584
# Epoch 2/50
# 5600/5600 [==============================] - 53s 9ms/step - loss: 2.4067 - val_loss: 2.4421
# Epoch 3/50
# 5600/5600 [==============================] - 53s 9ms/step - loss: 2.3912 - val_loss: 2.4263
# Epoch 4/50
# 5600/5600 [==============================] - 50s 9ms/step - loss: 2.3630 - val_loss: 2.4021
# Epoch 5/50
# 5600/5600 [==============================] - 49s 9ms/step - loss: 2.3390 - val_loss: 2.3724
# Epoch 6/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 2.3083 - val_loss: 2.3365
# Epoch 7/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 2.2884 - val_loss: 2.3068
# Epoch 8/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 2.2508 - val_loss: 2.2755
# Epoch 9/50
# ...

# %%
# %%capture
x_test, y_test = getData(17090, 18000)

# %%
np.save('x_17090-18000.npy', x_test)
np.save('y_17090-18000.npy', y_test)

# %%
x_2 = np.load('x_17090-18000.npy')
y_2 = np.load('y_17090-18000.npy')

# %%
#x_2 = np.expand_dims(x_2, axis=1)
#print(x_2.shape)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# l1 (Dense)                   (None, 900)               927900
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 30, 10, 3)         0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 38, 18, 18)        4392
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 38, 18, 18)        72
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 12312)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 784)               9653392
# ...
# Total params: 10,585,756
# Trainable params: 10,585,720
# Non-trainable params: 36
# _________________________________________________________________

# %%
y_predict = model.predict(x_2)
for i in range(10):
    print("Image ", (17090 + i))
    displayImage(y_2[i])
    displayImage(y_predict[i])
# Out:
# Image  17090
# Image  17091
# Image  17092
# Image  17093
# Image  17094
# Image  17095
# Image  17096
# Image  17097
# Image  17098
# Image  17099

# %%
plt.plot(info.history['loss'])
plt.plot(info.history['val_loss'])
plt.title('Model error')
plt.ylabel('error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

print("Loss: ", info.history['loss'])
# Out:
# Loss:  [2.6220317677089144, 2.4066531453813824, 2.391153529030936, 2.3630258342197963, 2.3389996474129813, 2.308313755307879, 2.288353097098214, 2.2507865905761717, 2.3015748378208705, 2.238379189627511, 2.2199175943647114, 2.2071047524043492, 2.19667069707598, 2.185023488998413, 2.169076791490827, 2.134189875466483, 2.0969087096623014, 2.054704851422991, 1.5573215287072317, 0.513204025881631, 0.45087679488318305, 0.4271856481688363, 0.4098981130123138, 0.39625637667519703, 0.3849605390003749, 0.37204381857599533, 0.3628499262673514, 0.35425569415092467, 0.34779706052371434, 0.3407122812952314, 0.33508617571422034, 0.3338919634478433, 0.3257735071863447, 0.3173594764300755, 0.31311300703457423, 0.30880379915237427, 0.3041189696107592, 0.3009132046358926, 0.29708936384746004, 0.29436004332133703, 0.2913097548484802, 0.2885042977333069, 0.286182696393558, 0.28079774362700327, 0.2783877841063908, 0.2764285664899009, 0.27552194067410063, 0.2713175695283072, 0.26994406138147625, 0.2649699
# ...

# %% [markdown]
# ## Changing Parameters

# %%
# Neural Net
model1 = Sequential()
model1.add(Dense(900, input_dim=INPUT_SIZE, activation='sigmoid', name='l1'))
model1.add(core.Reshape((30, 10, 3)))
model1.add(Conv2DTranspose(18, 9, activation='sigmoid', input_shape=(30, 30, 1)))
model1.add(BatchNormalization(axis=-1))
model1.add(Flatten())
model1.add(Dense(OUTPUT_SIZE, activation='relu'))
model1.compile(loss='mse', optimizer='adam')
info = model1.fit(x_1, y_1, epochs=50, batch_size=64, validation_split=0.3)
# Out:
# Train on 5600 samples, validate on 2400 samples
# Epoch 1/50
# 5600/5600 [==============================] - 58s 10ms/step - loss: 1.9893 - val_loss: 1.0849
# Epoch 2/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 0.8938 - val_loss: 0.8386
# Epoch 3/50
# 5600/5600 [==============================] - 54s 10ms/step - loss: 0.7727 - val_loss: 0.7395
# Epoch 4/50
# 5600/5600 [==============================] - 49s 9ms/step - loss: 0.6886 - val_loss: 0.6934
# Epoch 5/50
# 5600/5600 [==============================] - 51s 9ms/step - loss: 0.6427 - val_loss: 0.6475
# Epoch 6/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 0.5912 - val_loss: 0.6121
# Epoch 7/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.5636 - val_loss: 0.5926
# Epoch 8/50
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.5248 - val_loss: 0.5486
# Epoch 9/50
# ...

# %%
plt.plot(info.history['loss'])
plt.plot(info.history['val_loss'])
plt.title('Model error')
plt.ylabel('error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

print("Loss: ", info.history['loss'])
# Out:
# Loss:  [1.9893452494485038, 0.8938071496146066, 0.7727424308231898, 0.6886359899384635, 0.6426864644459316, 0.591163934298924, 0.5635914647579193, 0.5248476954868861, 0.49403170653751916, 0.4769378801754543, 0.4633044345038278, 0.4469167801312038, 0.4323864758014679, 0.4184715972627912, 0.39965407916477746, 0.38726477537836346, 0.38138797862189155, 0.3731012397153037, 0.3646081066131592, 0.36025651250566754, 0.35371401054518564, 0.3462556808335441, 0.33971906917435785, 0.33175030980791365, 0.32441598449434556, 0.3206006853921073, 0.31438230565616065, 0.31146610975265504, 0.3091135696002415, 0.3054844224452972, 0.3018009945324489, 0.29800347328186033, 0.2946303391456604, 0.29098583919661386, 0.28928073150771005, 0.2859469469955989, 0.28156936747687206, 0.2768204018047878, 0.2750006706374032, 0.27184946724346704, 0.27384034769875665, 0.2697498938015529, 0.2659373928819384, 0.2630624767712184, 0.2612476074695587, 0.2586319521495274, 0.25591752767562864, 0.25634102531841824, 0.2536334543
# ...

# %%
# Neural Net
model1 = Sequential()
model1.add(Dense(900, input_dim=INPUT_SIZE, activation='sigmoid', name='l1'))
model1.add(core.Reshape((30, 10, 3)))
model1.add(Conv2DTranspose(18, 9, activation='sigmoid', input_shape=(60, 30, 5)))
model1.add(BatchNormalization(axis=-1))
model1.add(Flatten())
model1.add(Dense(OUTPUT_SIZE, activation='relu'))
model1.compile(loss='mse', optimizer='adam')
info = model1.fit(x_1, y_1, epochs=50, batch_size=64, validation_split=0.3)
