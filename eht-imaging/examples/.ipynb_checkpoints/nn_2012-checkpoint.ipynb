# %% [markdown]
# Inspired by an image deblurring paper: https://ieeexplore.ieee.org/document/6420015

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, Conv2D, Flatten, core, BatchNormalization, Conv2DTranspose
import ehtim as eh
import numpy as np

# visibilities
INPUT_SIZE = 1030
# pixels in image
OUTPUT_SIZE = 784

# %%
IM = eh.image.load_txt('../models/avery_sgra_eofn.txt');
IM = IM.resample_square(28)

def displayImage(arr):
    """Displays image given a flattened array of pixels."""
    IM.imvec = arr
    IM.display()

# %%
def getData(start, end):
    """Reads in visibilities and image from [start, end)."""
    n = end - start
    x, y = np.empty([n, INPUT_SIZE]), np.empty([n, OUTPUT_SIZE])
    for i in range(n):
        obs = eh.obsdata.load_uvfits('../data/trainA/obs{0}.fits'.format(start + i))
        im = eh.image.load_fits('../data/trainB/img{0}.fits'.format(start + i))
        x[i] = obs.data['vis']
        y[i] = im.imvec
    return x, y

# %%
#x_train, y_train = getData(10000, 18000)

# %%
np.save('x_10000-18000.npy', x_train)
np.save('y_10000-18000.npy', y_train)

# %%
x_1 = np.load('x_10000-18000.npy')
y_1 = np.load('y_10000-18000.npy')

# %%
for i in range(0,len(y_1)):
    y_1[i] = y_1[i] * 784

# %%
print(x_1.shape)
# Out:
# (8000, 1030)

# %%
# Neural Net
model = Sequential()
model.add(Dense(900, input_dim=INPUT_SIZE, activation='sigmoid', name='l1'))
model.add(core.Reshape((30, 30, 1)))
model.add(Conv2DTranspose(18, 1, activation='sigmoid', input_shape=(30, 30, 1)))
model.add(BatchNormalization(axis=-1))
model.add(Flatten())
model.add(Dense(OUTPUT_SIZE, activation='relu'))
model.compile(loss='mse', optimizer='adam')
model.fit(x_1, y_1, epochs=10, batch_size=64, validation_split=0.3)
# Out:
# Train on 5600 samples, validate on 2400 samples
# Epoch 1/10
# 5600/5600 [==============================] - 47s 8ms/step - loss: 0.9673 - val_loss: 0.7034
# Epoch 2/10
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.6149 - val_loss: 0.6147
# Epoch 3/10
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.5718 - val_loss: 0.6097
# Epoch 4/10
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.5551 - val_loss: 0.5952
# Epoch 5/10
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.5341 - val_loss: 0.5634
# Epoch 6/10
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.5165 - val_loss: 0.5688
# Epoch 7/10
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.5079 - val_loss: 0.5561
# Epoch 8/10
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.4993 - val_loss: 0.5390
# Epoch 9/10
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.4973 - val_loss: 0.5627
# Epoch 10/10
# 5600/5600 [==============================] - 42s 7ms/step - loss: 0.4923 - val_loss: 0.5422

# %%
# %%capture
x_test, y_test = getData(17090, 18000)

# %%
np.save('x_17090-18000.npy', x_test)
np.save('y_17090-18000.npy', y_test)

# %%
x_2 = np.load('x_17090-18000.npy')
y_2 = np.load('y_17090-18000.npy')

# %%
#x_2 = np.expand_dims(x_2, axis=1)
print(x_2.shape)
# Out:
# (910, 1030)

# %%
y_predict = model.predict(x_2)
for i in range(10):
    print("Image ", (17090 + i))
    displayImage(y_2[i])
    displayImage(y_predict[i])
# Out:
# Image  17090
# Image  17091
# Image  17092
# Image  17093
# Image  17094
# Image  17095
# Image  17096
# Image  17097
# Image  17098
# Image  17099

# %% [markdown]
# ## Summary of layers

# %%
ix = 1
for layer in model.layers:
    # check for convolutional layer
    if 'conv' not in layer.name:
        continue
    # get filter weights
    filters, biases = layer.get_weights()
    print(layer.name, filters.shape)
    f_min, f_max = filters.min(), filters.max()
    filters = (filters - f_min) / (f_max - f_min)
    ax = pyplot.subplot(1, 3, ix)
    ax.set_xticks([])
    ax.set_yticks([])
    # plot filter channel in grayscale
    pyplot.imshow(f[:, :, j], cmap='gray')
    ix += 1
    pyplot.show()
